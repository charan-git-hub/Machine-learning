# %% [markdown]
# ## Supervised Learning

# %% [markdown]
# - Supervised learning is a category of machine learning that uses labeled datasets to train algorithms to predict outcomes and recognize patterns.

# %% [markdown]
# ![supervised-machine-learning.png](attachment:7648bb57-def6-4e76-8bb5-de6fb98c9731.png)

# %% [markdown]
# ## Supervised Learning Algorithms

# %% [markdown]
# - Linear Regression
# - Logistic Regression
# - Decision Trees
# - Random Forest
# - Support Vector Machine(SVM)
# - K-Nearest Neighbors (KNN)

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# - Linear regression is a statistical method used for modeling the relationship between a dependent variable and one or more independent variables by fitting a linear equation to the observed data.
# -
# The basic idea is to find the best-fitting straight line (or hyperplane in the case of multiple independent variables) that minimizes the difference between the observed and predicted values of the dependent variable.

# %% [markdown]
# ![linear-regression-in-machine-learning.png](attachment:9719802a-e426-44d8-9883-56f1b099933b.png)

# %% [markdown]
# ## Types of Linear Regression

# %% [markdown]
# Linear regression can be further divided into two types of the algorithm:
#
# 1. Simple Linear Regression
# 2. Muliple Linear regression

# %% [markdown]
# ## 1. Simple Linear Regression

# %% [markdown]
# - If a single independent variable is used to predict the value of a numerical dependent variable, then such a Linear Regression algorithm is called Simple Linear Regression.

# %% [markdown]
# ## Formula

# %% [markdown]
# ![download.png](attachment:a7e71116-5c4c-4f16-8002-a397f3c64fe7.png)

# %% [markdown]
# - Y = mx + c

# %% [markdown]
# ## 2.Multiple Linear regression:

# %% [markdown]
# - If more than one independent variable is used to predict the value of a numerical dependent variable, then such a Linear Regression algorithm is called Multiple Linear Regression.

# %% [markdown]
# ## Formula

# %% [markdown]
# ![download.png](attachment:1364ad28-c243-4bf3-b4c5-785233767573.png)

# %% [markdown]
# ## Linear Regression Line

# %% [markdown]
# - A linear line showing the relationship between the dependent and independent variables is called a **regression line**. A regression line can show two types of relationship:

# %% [markdown]
# ## Positive Linear Relationship:

# %% [markdown]
# - If the dependent variable increases on the Y-axis and independent variable increases on X-axis, then such a relationship is termed as a Positive linear relationship.

# %% [markdown]
# ![linear-regression-in-machine-learning2.png](attachment:4c1be864-073c-4398-be6a-0f6c354250d4.png)

# %% [markdown]
# ## Negative Linear Relationship:

# %% [markdown]
# - If the dependent variable decreases on the Y-axis and independent variable increases on the X-axis, then such a relationship is called a negative linear relationship.

# %% [markdown]
# ![linear-regression-in-machine-learning3.png](attachment:49578b20-6612-474b-9967-73384385b6e6.png)

# %% [markdown]
# ## Finding the best fit line

# %% [markdown]
# - When working with linear regression, our main goal is to find the best fit line that means the error between predicted values and actual values should be minimized.
# - The best fit line will have the least error.

# %% [markdown]
# ## Mean Squared Error (MSE)

# %% [markdown]
# - For Linear Regression, we use the **Mean Squared Error (MSE)** cost function, which is the average of squared error occurred between the predicted values and actual values. It can be written as:
#
# For the above linear equation, MSE can be calculated as:

# %% [markdown]
# ![linear-regression-in-machine-learning4.png](attachment:17de5a88-e072-44ea-aa70-f6170cdc50a3.png)

# %% [markdown]
# Where,
#
# - N=Total number of observation
# - Yi = Actual value
# - (a1xi+a0)= Predicted value.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt

# Given data points
y_test = np.array([1, 3, 5, 2, 4])
y_pred = np.array([3, 2, 1, 4, 2])

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

mean_y = np.mean(y_test)

mse_percentage = (mse / mean_y) * 100

mse_percentage = 193.33  # Example value
min_percentage = 1       # Define minimum bound
max_percentage = 200     # Define maximum bound for normalization

# Normalize percentage to range 1–100
scaled_mse_percentage = ((mse_percentage - min_percentage) / (max_percentage - min_percentage)) * 100

print(f"Scaled MSE Percentage (1–100 range): {scaled_mse_percentage:.2f}")

mae_percentage = (mae / mean_y) * 100
rmse_percentage = (rmse / mean_y) * 100

#print(f"Mean Squared Error (MSE): {mse:.2f} ({mse_percentage:.2f}%)")
print(f"Mean Absolute Error (MAE): {mae:.2f} ({mae_percentage:.2f}%)")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f} ({rmse_percentage:.2f}%)")
# Out:
# Scaled MSE Percentage (1–100 range): 96.65
# Mean Absolute Error (MAE): 2.20 (73.33%)
# Root Mean Squared Error (RMSE): 2.41 (80.28%)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Data points
x = np.array([1, 3, 5, 2, 4]).reshape(-1, 1)  # Reshape for sklearn
y = np.array([3, 2, 1, 4, 2])

# Linear Regression Model
linear_model = LinearRegression()
linear_model.fit(x, y)

# Predictions
y_pred = linear_model.predict(x)

# Coefficients and R-squared
m = linear_model.coef_[0]
c = linear_model.intercept_
r2 = r2_score(y, y_pred)

# Plot errors
for i in range(len(x)):
    plt.plot([x[i], x[i]], [y[i], y_pred[i]], color='green', linestyle='--')

print(f"Linear Regression Equation: y = {m:.2f}x + {c:.2f}")
print(f"R^2 Score: {r2:.4f}")

# Plot the results
plt.scatter(x, y, color='blue', label='Actual data')
plt.plot(x, y_pred, color='red', label=f'Best Fit Line (R^2 = {r2:.2f})')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()
plt.grid()
plt.show()
# Out:
# Linear Regression Equation: y = -0.60x + 4.20
# R^2 Score: 0.6923

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn import metrics

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\cardata.csv")

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# ### Data Preprocessing

# %%
data['Car_Age'] = 2025 - data['Year']
data.drop('Year',axis=1,inplace=True)

# %%
data.rename(columns = {'Selling_Price':'Selling_Price(lacs)','Present_Price':'Present_Price(lacs)','Owner':'Past_Owner'},inplace=True)

# %%
data.columns
# Out:
# Index(['Car_Name', 'Selling_Price(lacs)', 'Present_Price(lacs)', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Past_Owner', 'Car_Age'],
#       dtype='object')

# %%
data.head(2)
# Out:
#   Car_Name  Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven Fuel_Type  \
# 0     ritz                 3.35                 5.59       27000    Petrol
# 1      sx4                 4.75                 9.54       43000    Diesel
#
#   Seller_Type Transmission  Past_Owner  Car_Age
# 0      Dealer       Manual           0       11
# 1      Dealer       Manual           0       12

# %%
cat_cols = ['Car_Age','Fuel_Type','Seller_Type','Transmission']
i=0
while i < 4:
    fig = plt.figure(figsize=[10,4])
    plt.subplot(1,2,1)
    sns.countplot(x=cat_cols[i],data=data)
    i += 1
    
    plt.subplot(1,2,2)
    sns.countplot(x=cat_cols[i],data=data)
    i += 1
    plt.show()

# %%
num_cols = ['Selling_Price(lacs)', 'Present_Price(lacs)', 'Kms_Driven','Car_Age']
i=0
while i < 4:
    fig = plt.figure(figsize=[13,3])
    plt.subplot(1,2,1)
    sns.boxplot(x=num_cols[i], data=data)
    i += 1
    plt.subplot(1,2,2)
    sns.boxplot(x=num_cols[i], data=data)
    i += 1
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
label_encoder = LabelEncoder()

# Apply label encoding
data['Car_Name_Encoded'] = label_encoder.fit_transform(data['Car_Name'])

# View the first few rows to check the transformation
data[['Car_Name', 'Car_Name_Encoded']].head()
# Out:
#   Car_Name  Car_Name_Encoded
# 0     ritz                90
# 1      sx4                93
# 2     ciaz                68
# 3  wagon r                96
# 4    swift                92

# %%
data
# Out:
#     Car_Name  Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven Fuel_Type  \
# 0       ritz                 3.35                 5.59       27000    Petrol
# 1        sx4                 4.75                 9.54       43000    Diesel
# 2       ciaz                 7.25                 9.85        6900    Petrol
# 3    wagon r                 2.85                 4.15        5200    Petrol
# 4      swift                 4.60                 6.87       42450    Diesel
# ..       ...                  ...                  ...         ...       ...
# 296     city                 9.50                11.60       33988    Diesel
# 297     brio                 4.00                 5.90       60000    Petrol
# 298     city                 3.35                11.00       87934    Petrol
# 299     city                11.50                12.50        9000    Diesel
# 300     brio                 5.30                 5.90        5464    Petrol
#
# ...

# %%
data.drop(labels='Car_Name',axis=1,inplace=True)

# %%
data
# Out:
#      Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven Fuel_Type  \
# 0                   3.35                 5.59       27000    Petrol
# 1                   4.75                 9.54       43000    Diesel
# 2                   7.25                 9.85        6900    Petrol
# 3                   2.85                 4.15        5200    Petrol
# 4                   4.60                 6.87       42450    Diesel
# ..                   ...                  ...         ...       ...
# 296                 9.50                11.60       33988    Diesel
# 297                 4.00                 5.90       60000    Petrol
# 298                 3.35                11.00       87934    Petrol
# 299                11.50                12.50        9000    Diesel
# 300                 5.30                 5.90        5464    Petrol
#
#     Seller_Type Transmission  Past_Owner  Car_Age  Car_Name_Encoded
# 0        Dealer       Manual           0       11                90
# ...

# %%
data = pd.get_dummies(data=data, drop_first=True)

# %%
data.head()
# Out:
#    Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven  Past_Owner  Car_Age  \
# 0                 3.35                 5.59       27000           0       11
# 1                 4.75                 9.54       43000           0       12
# 2                 7.25                 9.85        6900           0        8
# 3                 2.85                 4.15        5200           0       14
# 4                 4.60                 6.87       42450           0       11
#
#    Car_Name_Encoded  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0                90             False              True
# 1                93              True             False
# 2                68             False              True
# 3                96             False              True
# 4                92              True             False
#
#    Seller_Type_Individual  Transmission_Manual
# 0                   False                 True
# 1                   False                 True
# ...

# %%
data = data.apply(lambda col: col.astype(int) if col.dtype == 'bool' else col)

# %%
data.head()
# Out:
#    Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven  Past_Owner  Car_Age  \
# 0                 3.35                 5.59       27000           0       11
# 1                 4.75                 9.54       43000           0       12
# 2                 7.25                 9.85        6900           0        8
# 3                 2.85                 4.15        5200           0       14
# 4                 4.60                 6.87       42450           0       11
#
#    Car_Name_Encoded  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0                90                 0                 1
# 1                93                 1                 0
# 2                68                 0                 1
# 3                96                 0                 1
# 4                92                 1                 0
#
#    Seller_Type_Individual  Transmission_Manual
# 0                       0                    1
# 1                       0                    1
# ...

# %% [markdown]
# ### Train - Test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Splitting the data into features (X) and target (y)
X = data.drop(columns=['Selling_Price(lacs)'])  # Assuming 'Selling_Price' is the target
y = data['Selling_Price(lacs)']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)*100

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 2.163591213218935
# R-squared: 91.44058256336149

# %%
x = data.drop('Selling_Price(lacs)',axis=1)

# %%
y=data['Selling_Price(lacs)']

# %%
x.head()
# Out:
#    Present_Price(lacs)  Kms_Driven  Past_Owner  Car_Age  Car_Name_Encoded  \
# 0                 5.59       27000           0       11                90
# 1                 9.54       43000           0       12                93
# 2                 9.85        6900           0        8                68
# 3                 4.15        5200           0       14                96
# 4                 6.87       42450           0       11                92
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price(lacs), dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
print("x train",x_train.shape)
print("y train",y_train.shape)
print("x test",x_test.shape)
print("y test",y_test.shape)
# Out:
# x train (210, 9)
# y train (210,)
# x test (91, 9)
# y test (91,)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 7.56168397, -0.38139188,  4.30198736,  8.99877208, 14.04214731,
#         4.90865402,  3.57786847,  1.39660904,  5.29037172,  4.59908238,
#         2.41592758,  1.58306014,  5.05887097,  7.39747943,  8.61317863,
#        13.39415101,  7.16389262,  4.27321994, -0.41909709,  2.22610757,
#         4.92814826,  3.96855367,  6.2930716 ,  7.84060211, -1.78078936,
#         1.80888094, -0.77137887,  0.77648258,  0.05244933,  6.90919009,
#         3.90523801,  7.50775464,  0.71539938,  8.00171033,  3.57546801,
#         1.70022577,  5.50958234,  7.09053854, -2.40244335,  9.05249687,
#         9.18068792, 19.25249782,  4.42262136,  3.96136964,  6.7871484 ,
#         9.78061187,  0.13073767,  1.58860452,  5.08637633,  7.41760183,
#         7.86979868,  4.24215458,  4.81961711, 19.58144537,  1.64464784,
#         1.22260313,  0.31334838,  2.14208582,  3.44547591,  0.88660018,
#         3.53720118,  6.90180915,  2.71595106, 20.66370513,  4.34857673,
# ...

# %%
print("Coefficients:",model.coef_)
print("Intercept:",model.intercept_)
# Out:
# Coefficients: [ 3.98630258e-01 -5.97612204e-06 -8.24842134e-01 -3.64804291e-01
#  -1.26373361e-03  2.65287931e+00  6.33608246e-01 -1.43077222e+00
#  -1.32977059e+00]
# Intercept: 6.625105042430755

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 4.432623628882182

# %%
# Calculate RMSE
rmse = np.sqrt(mse)

# Calculate the mean of actual values
mean_y = np.mean(y_test)

# Calculate RMSE as a percentage
rmse_percentage = (rmse / mean_y) * 100

print(f"RMSE: {rmse}")
print(f"Mean of Actual Values: {mean_y}")
print(f"RMSE Percentage: {rmse_percentage:.2f}%")
# Out:
# RMSE: 2.1053796875818342
# Mean of Actual Values: 5.127802197802198
# RMSE Percentage: 41.06%

# %%
error = y_test - y_pred
print(error)
# Out:
# 223    0.688316
# 150    0.881392
# 226    0.948013
# 296    0.501228
# 52     3.957853
#          ...
# 240   -1.290931
# 76    -1.383178
# 145    0.699392
# 300    0.418437
# 135   -0.447541
# Name: Selling_Price(lacs), Length: 91, dtype: float64

# %%
sns.regplot(x=y_pred, y=error, data=data)
# Out:
# <Axes: ylabel='Selling_Price(lacs)'>

# %%
residuals = y_test - y_pred
plt.figure(figsize=(10, 6))
sns.regplot(x=y_pred, y=residuals, scatter_kws={"color": "red", "s": 50}, line_kws={"color": "green", "linewidth": 2})
plt.title(f"Residuals (Mean Squared Error: {mse:.2f})")
plt.xlabel('Predicted Selling Price')
plt.ylabel('Residuals')
plt.show()

# %%
x = data.drop('Selling_Price(lacs)',axis=1)

# %%
y=data['Selling_Price(lacs)']

# %%
x.head()
# Out:
#    Present_Price(lacs)  Kms_Driven  Past_Owner  Car_Age  Car_Name_Encoded  \
# 0                 5.59       27000           0       11                90
# 1                 9.54       43000           0       12                93
# 2                 9.85        6900           0        8                68
# 3                 4.15        5200           0       14                96
# 4                 6.87       42450           0       11                92
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price(lacs), dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 7.52212954, -0.37627659,  4.25843594,  9.00323605, 14.42854235,
#         4.86855659,  3.5106244 ,  1.44443377,  5.3484622 ,  4.62014271,
#         2.26961136,  1.6117923 ,  5.05307923,  7.55727225,  8.60490883,
#        13.9874215 ,  7.33247354,  4.23187221, -0.43215664,  2.37710811,
#         4.99466997,  3.82764497,  6.43899166,  8.01949392, -1.90222349,
#         1.93847088, -0.82574167,  0.82099017,  0.02219663,  7.0958865 ,
#         3.56594406,  7.42576698,  0.71399183,  7.93136998,  3.51263464,
#         1.80993267,  5.54944164,  6.98727617, -2.63780077,  9.08215145,
#         9.21935774, 20.02127666,  4.38216372,  3.86061926,  6.66086182,
#         9.84514056,  0.13211294,  1.68477244,  5.09723229,  7.355595  ,
#         8.06942154,  4.17254793,  4.8555076 , 20.36783473,  1.75292938,
#         1.30710682,  0.30190038,  1.98576023,  3.38085998,  0.88035697,
#         3.52933645])

# %%
print("Coefficients:",model.coef_)
print("Intercept:",model.intercept_)
# Out:
# Coefficients: [ 4.26420795e-01 -6.12938559e-06 -9.43976386e-01 -3.83334385e-01
#   3.30235495e-04  2.49696253e+00  5.90021855e-01 -1.12757763e+00
#  -1.43611525e+00]
# Intercept: 6.631456319914411

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred)*100
print("R-squared:",r2)
# Out:
# R-squared: 91.44058256336149

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.regplot(x=y_test, y=y_pred, line_kws={"color": "blue", "linewidth": 2})
plt.title(f"Actual vs Predicted (R-squared: {r2:.2f})")
plt.xlabel('Actual Selling Price')
plt.ylabel('Predicted Selling Price')
plt.show()
