# %% [markdown]
# # K-Means Clustering Algorithm

# %% [markdown]
# K-Means Clustering is an unsupervised learning algorithm that is used to solve the clustering problems in machine learning or data science. In this topic, we will learn what is K-means clustering algorithm, how the algorithm works, along with the Python implementation of k-means clustering.

# %% [markdown]
# - K-means clustering is a popular unsupervised machine learning algorithm used for grouping similar data points together. Here's a breakdown of the concept:
#
#
# What it Does:
#
# - K-means partitions your data into a predetermined number of clusters (groups).
#
# - It aims to create clusters where the data points within each cluster are similar to each other and dissimilar to data points in other clusters.
#
#
# How it Works:
#
# - **Define the Number of Clusters (K)**: You need to specify the desired number of clusters (K) beforehand. This is a crucial step as it significantly affects the outcome.
#
# - **Initialize Centroids**: The algorithm randomly selects K data points as initial cluster centers, also called centroids. These centroids represent the "center" of each cluster.
#
# - **Assign Data Points**: Each data point is assigned to the closest centroid based on a distance metric, usually Euclidean distance.
#
# - **Recompute Centroids**: Once all data points are assigned, the centroids are recomputed as the average of the data points in their respective clusters.
#
# - **Repeat and Refine**: Steps 3 and 4 are repeated iteratively. In each iteration, data points are reassigned to the closest centroid based on the updated centroids. This process continues until a stopping criterion is met, such as no further changes in cluster assignments.

# %% [markdown]
# ![download.png](attachment:93f4aabe-88e3-4b6d-a36d-96368ef1ea5a.png)

# %% [markdown]
# ## What is K-Means Algorithm?

# %% [markdown]
# - K-Means Clustering is an Unsupervised Learning algorithm, which groups the unlabeled dataset into different clusters. Here K defines the number of pre-defined clusters that need to be created in the process, as if K=2, there will be two clusters, and for K=3, there will be three clusters, and so on.
#
# - It is an iterative algorithm that divides the unlabeled dataset into k different clusters in such a way that each dataset belongs only one group that has similar properties.
#
# - It allows us to cluster the data into different groups and a convenient way to discover the categories of groups in the unlabeled dataset on its own without the need for any training.
#
# - It is a centroid-based algorithm, where each cluster is associated with a centroid. The main aim of this algorithm is to minimize the sum of distances between the data point and their corresponding clusters.
#
# - The algorithm takes the unlabeled dataset as input, divides the dataset into k-number of clusters, and repeats the process until it does not find the best clusters. The value of k should be predetermined in this algorithm.
#
# The k-means clustering algorithm mainly performs two tasks:
#
# - Determines the best value for K center points or centroids by an iterative process.
#
# - Assigns each data point to its closest k-center. Those data points which are near to the particular k-center, create a cluster.
#
# Hence each cluster has datapoints with some commonalities, and it is away from other clusters.
#
# The below diagram explains the working of the K-means Clustering Algorithm:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning.png](attachment:83121e27-189c-4cd7-817f-4a3a27d54a00.png)

# %% [markdown]
# ## How does the K-Means Algorithm Work?

# %% [markdown]
# The working of the K-Means algorithm is explained in the below steps:
#
# **Step-1**: Select the number K to decide the number of clusters.
#
# **Step-2**: Select random K points or centroids. (It can be other from the input dataset).
#
# **Step-3**: Assign each data point to their closest centroid, which will form the predefined K clusters.
#
# **Step-4**: Calculate the variance and place a new centroid of each cluster.
#
# **Step-5**: Repeat the third steps, which means reassign each datapoint to the new closest centroid of each cluster.
#
# **Step-6**: If any reassignment occurs, then go to step-4 else go to FINISH.
#
# **Step-7**: The model is ready.
#
# Let's understand the above steps by considering the visual plots:
#
# Suppose we have two variables M1 and M2. The x-y axis scatter plot of these two variables is given below:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning2.png](attachment:f5a0bea3-5972-4426-a789-d0c4db7e07ca.png)

# %% [markdown]
# - Let's take number k of clusters, i.e., K=2, to identify the dataset and to put them into different clusters. It means here we will try to group these datasets into two different clusters.
#
# - We need to choose some random k points or centroid to form the cluster. These points can be either the points from the dataset or any other point. So, here we are selecting the below two points as k points, which are not the part of our dataset. Consider the below image:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning3.png](attachment:9b318605-cc17-48e5-b79e-fed6f1ff1994.png)

# %% [markdown]
# - Now we will assign each data point of the scatter plot to its closest K-point or centroid. We will compute it by applying some mathematics that we have studied to calculate the distance between two points. So, we will draw a median between both the centroids. Consider the below image:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning4.png](attachment:59fa120f-fb8b-46f5-be74-5f73d3ae7659.png)

# %% [markdown]
# From the above image, it is clear that points left side of the line is near to the K1 or blue centroid, and points to the right of the line are close to the yellow centroid. Let's color them as blue and yellow for clear visualization.

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning5.png](attachment:003bcd14-663a-4af1-96d0-20db8f5cfce0.png)

# %% [markdown]
# - As we need to find the closest cluster, so we will repeat the process by choosing a new centroid. To choose the **new centroids**, we will compute the center of gravity of these centroids, and will find new centroids as below:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning6.png](attachment:f4f2d189-7338-4bb7-9c3a-d51a1f410b4e.png)

# %% [markdown]
# - Next, we will reassign each datapoint to the new centroid. For this, we will repeat the same process of finding a median line. The median will be like below image:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning7.png](attachment:2af06e3a-3113-449f-91c2-a94bb9be486c.png)

# %% [markdown]
# From the above image, we can see, one yellow point is on the left side of the line, and two blue points are right to the line. So, these three points will be assigned to new centroids.

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning8.png](attachment:af8d7857-e6e0-48b4-babe-c898e99e21bd.png)

# %% [markdown]
# As reassignment has taken place, so we will again go to the step-4, which is finding new centroids or K-points.
#
# - We will repeat the process by finding the center of gravity of centroids, so the new centroids will be as shown in the below image:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning9.png](attachment:a01ee08d-f573-4710-87f2-6d54410eace0.png)

# %% [markdown]
# - As we got the new centroids so again will draw the median line and reassign the data points. So, the image will be:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning10.png](attachment:9153f9c3-6a2b-4e66-88f0-05aba8dd7ff9.png)

# %% [markdown]
# - We can see in the above image; there are no dissimilar data points on either side of the line, which means our model is formed. Consider the below image:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning11.png](attachment:0e072002-6a6a-4a8c-b835-914beff68b26.png)

# %% [markdown]
# As our model is ready, so we can now remove the assumed centroids, and the two final clusters will be as shown in the below image:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning12.png](attachment:81951c1b-c105-4ada-85d9-5c9599cf1b06.png)

# %% [markdown]
# ## How to choose the value of "K number of clusters" in K-means Clustering?

# %% [markdown]
# The performance of the K-means clustering algorithm depends upon highly efficient clusters that it forms. But choosing the optimal number of clusters is a big task. There are some different ways to find the optimal number of clusters, but here we are discussing the most appropriate method to find the number of clusters or value of K. The method is given below:

# %% [markdown]
# ## Elbow Method

# %% [markdown]
# The Elbow method is one of the most popular ways to find the optimal number of clusters in K-Means clustering. This method uses the concept of **WCSS (Within Cluster Sum of Squares)**.
#
# WCSS defines the total variations within a cluster and is calculated as the sum of the squared distances between each data point and its cluster centroid.
#
#
# ## Formula for WCSS (for 3 clusters):
#
# $$
# WCSS = \sum_{P_i \in \text{Cluster1}} \text{distance}(P_i, C1)^2 +
# \sum_{P_i \in \text{Cluster2}} \text{distance}(P_i, C2)^2 +
# \sum_{P_i \in \text{Cluster3}} \text{distance}(P_i, C3)^2
# $$
#
# ### Explanation of the Terms:
# - $ \sum_{P_i \in \text{Cluster1}} \text{distance}(P_i, C1)^2 $:
#   Sum of the square of the distances between each data point $ P_i $ and the centroid $ C1 $ within Cluster 1.
# - The same calculation applies to Cluster 2 and Cluster 3.
#
# To calculate the distance between data points and centroids, common methods include:
# - **Euclidean Distance**
# - **Manhattan Distance**
#
#
#
# ## Steps for the Elbow Method:
#
# 1. Execute the K-Means clustering algorithm on the dataset for different values of $ K $ (e.g., 1 to 10).
# 2. For each value of $ K $, calculate the **WCSS**.
# 3. Plot a curve between the **WCSS values** and the **number of clusters (K)**.
# 4. Identify the "sharp bend" in the graph, which resembles an elbow.
#    - The **optimal value of $ K $** corresponds to this point.
#
#
# ### Why "Elbow" Method?
#
# The graph resembles an elbow shape, where the WCSS decreases significantly at first, but the rate of decrease slows down beyond a certain point. This **sharp bend** indicates the optimal number of clusters, as adding more clusters after this point does not significantly reduce WCSS.
#
#
#
# ### Applications:
# - Used in customer segmentation, image compression, and other clustering-based tasks to determine the ideal number of clusters.
#
#
# ### Example Graph:
#
# Since the graph shows the sharp bend, which looks like an elbow, hence it is known as the elbow method. The graph for the elbow method looks like the below image:

# %% [markdown]
# ![k-means-clustering-algorithm-in-machine-learning13.png](attachment:3e35119b-cda8-4105-93db-57401418565f.png)

# %% [markdown]
# **Note**: We can choose the number of clusters equal to the given data points. If we choose the number of clusters equal to the data points, then the value of WCSS becomes zero, and that will be the endpoint of the plot.

# %% [markdown]
# ## Implementation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\Live.csv")
data
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
data.head()
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
data.tail()
# Out:
#                               status_id status_type status_published  \
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 7045             89             0           0         89          0         0
# 7046             16             0           0         14          1         0
# 7047              2             0           0          1          1         0
# 7048            351            12          22        349          2         0
# 7049             17             0           0         17          0         0
#
#       num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
data.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys  Column1  Column2  \
# count  7050.000000  7050.000000  7050.000000  7050.000000      0.0      0.0
# mean      1.289362     0.696454     0.243688     0.113191      NaN      NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
data.isnull().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
data.shape
# Out:
# (7050, 16)

# %%
data.drop(['Column1', 'Column2', 'Column3', 'Column4'], axis=1, inplace=True)

# %%
data
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
data.isnull().sum()
# Out:
# status_id           0
# status_type         0
# status_published    0
# num_reactions       0
# num_comments        0
# num_shares          0
# num_likes           0
# num_loves           0
# num_wows            0
# num_hahas           0
# num_sads            0
# num_angrys          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
# dtypes: int64(9), object(3)
# memory usage: 661.1+ KB

# %%
# view the labels in the variable

data['status_id'].unique()
# Out:
# array(['246675545449582_1649696485147474',
#        '246675545449582_1649426988507757',
#        '246675545449582_1648730588577397', ...,
#        '1050855161656896_1060126464063099',
#        '1050855161656896_1058663487542730',
#        '1050855161656896_1050858841656528'], dtype=object)

# %%
# view the labels in the variable

data['status_published'].unique()
# Out:
# array(['4/22/2018 6:00', '4/21/2018 22:45', '4/21/2018 6:17', ...,
#        '9/21/2016 23:03', '9/20/2016 0:43', '9/10/2016 10:30'],
#       dtype=object)

# %%
# view how many different types of variables are there

len(data['status_published'].unique())
# Out:
# 6913

# %%
# view the labels in the variable

data['status_type'].unique()
# Out:
# array(['video', 'photo', 'link', 'status'], dtype=object)

# %%
# view how many different types of variables are there

len(data['status_type'].unique())
# Out:
# 4

# %%
data.drop(['status_id', 'status_published'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 550.9+ KB

# %%
data.head()
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video            529           512         262        432         92
# 1       photo            150             0           0        150          0
# 2       video            227           236          57        204         21
# 3       photo            111             0           0        111          0
# 4       photo            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
x = data
y = data['status_type']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

x['status_type'] = le.fit_transform(x['status_type'])

y = le.transform(y)

# %%
x.head()
# Out:
#    status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0            3            529           512         262        432         92
# 1            1            150             0           0        150          0
# 2            3            227           236          57        204         21
# 3            1            111             0           0        111          0
# 4            1            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
cols = x.columns

# %%
from sklearn.preprocessing import MinMaxScaler

ms = MinMaxScaler()

x = ms.fit_transform(x)

# %%
x = pd.DataFrame(x, columns=[cols])

# %%
x.head()
# Out:
#   status_type num_reactions num_comments num_shares num_likes num_loves  \
# 0    1.000000      0.112314     0.024393   0.076519  0.091720  0.140030
# 1    0.333333      0.031847     0.000000   0.000000  0.031847  0.000000
# 2    1.000000      0.048195     0.011243   0.016647  0.043312  0.031963
# 3    0.333333      0.023567     0.000000   0.000000  0.023567  0.000000
# 4    0.333333      0.045223     0.000000   0.000000  0.043312  0.013699
#
#    num_wows num_hahas  num_sads num_angrys
# 0  0.010791  0.006369  0.019608        0.0
# 1  0.000000  0.000000  0.000000        0.0
# 2  0.003597  0.006369  0.000000        0.0
# 3  0.000000  0.000000  0.000000        0.0
# 4  0.000000  0.000000  0.000000        0.0

# %%
from sklearn.cluster import KMeans
cs = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    cs.append(kmeans.inertia_)
plt.plot(range(1, 11), cs)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('CS')
# Out:
# Text(0, 0.5, 'CS')

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=0) 

kmeans.fit(x)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[9.54921576e-01, 6.46330441e-02, 2.67028654e-02, 2.93171709e-02,
#         5.71231462e-02, 4.71007076e-02, 8.18581889e-03, 9.65207685e-03,
#         8.04219428e-03, 7.19501847e-03],
#        [3.28506857e-01, 3.90710874e-02, 7.54854864e-04, 7.53667113e-04,
#         3.85438884e-02, 2.17448568e-03, 2.43721364e-03, 1.20039760e-03,
#         2.75348016e-03, 1.45313276e-03]])

# %%
kmeans.inertia_
# Out:
# 237.75726404419646

# %%
labels = kmeans.labels_

# check how many of the samples were correctly labeled
correct_labels = sum(y == labels)

print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
# Out:
# Result: 4288 out of 7050 samples were correctly labeled.

# %%
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Accuracy score: 0.61

# %%
# k= 3

kmeans = KMeans(n_clusters=3, random_state=0)

kmeans.fit(x)

# check how many of the samples were correctly labeled
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 4066 out of 7050 samples were correctly labeled.
# Accuracy score: 0.58

# %%
# k= 5

kmeans = KMeans(n_clusters=5, random_state=0)

kmeans.fit(x)

# check how many of the samples were correctly labeled
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 4080 out of 7050 samples were correctly labeled.
# Accuracy score: 0.58
